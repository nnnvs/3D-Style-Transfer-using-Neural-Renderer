# %%
# !pip install -r ../../requirements.txt
# Out:
# Collecting numpy
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 76 kB/s s eta 0:00:01
# Collecting scikit-image
#   Downloading scikit_image-0.17.2-cp36-cp36m-manylinux1_x86_64.whl (12.4 MB)
#      |████████████████████████████████| 12.4 MB 63 kB/s s eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 9.8 MB/s  eta 0:00:01
# Collecting imageio
#   Downloading imageio-2.15.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 113.0 MB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.3.4-cp36-cp36m-manylinux1_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 41.4 MB/s eta 0:00:01
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      |████████████████████████████████| 60.5 MB 40 kB/s /s eta 0:00:01
# Collecting scipy>=1.0.1
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 43.8 MB/s eta 0:00:01
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 52.2 MB/s eta 0:00:01
# Collecting networkx>=2.0
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 107.6 MB/s eta 0:00:01
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2020.9.3-py3-none-any.whl (148 kB)
#      |████████████████████████████████| 148 kB 151.3 MB/s eta 0:00:01
# Collecting pillow!=7.1.0,!=7.1.1,>=4.3.0
#   Downloading Pillow-8.4.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 133.2 MB/s eta 0:00:01
# Collecting importlib-resources
#   Downloading importlib_resources-5.4.0-py3-none-any.whl (28 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 139.1 MB/s eta 0:00:01
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 13.7 MB/s  eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting python-dateutil>=2.1
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 147.0 MB/s eta 0:00:01
# Collecting decorator<5,>=4.3
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting six>=1.5
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting zipp>=3.1.0
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Installing collected packages: six, zipp, python-dateutil, pyparsing, pillow, numpy, kiwisolver, decorator, cycler, tifffile, scipy, PyWavelets, networkx, matplotlib, importlib-resources, imageio, tqdm, scikit-image, opencv-python
# Successfully installed PyWavelets-1.1.1 cycler-0.11.0 decorator-4.4.2 imageio-2.15.0 importlib-resources-5.4.0 kiwisolver-1.3.1 matplotlib-3.3.4 networkx-2.5.1 numpy-1.19.5 opencv-python-4.5.5.64 pillow-8.4.0 pyparsing-3.0.9 python-dateutil-2.8.2 scikit-image-0.17.2 scipy-1.5.4 six-1.16.0 tifffile-2020.9.3 tqdm-4.64.0 zipp-3.6.0

# %%
# !pip3 install torch==1.8.1+cu102 torchvision==0.9.1+cu102 torchaudio===0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.8.1+cu102
#   Downloading https://download.pytorch.org/whl/cu102/torch-1.8.1%2Bcu102-cp36-cp36m-linux_x86_64.whl (804.1 MB)
#      |████████████████████████████████| 804.1 MB 31 kB/s  eta 0:00:0101
# Collecting torchvision==0.9.1+cu102
#   Downloading https://download.pytorch.org/whl/cu102/torchvision-0.9.1%2Bcu102-cp36-cp36m-linux_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 15.2 MB/s eta 0:00:01
# Collecting torchaudio===0.8.1
#   Downloading torchaudio-0.8.1-cp36-cp36m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 36.2 MB/s eta 0:00:01
# Collecting typing-extensions
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from torch==1.8.1+cu102) (1.19.5)
# Collecting dataclasses
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Requirement already satisfied: pillow>=4.1.1 in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from torchvision==0.9.1+cu102) (8.4.0)
# Installing collected packages: typing-extensions, dataclasses, torch, torchvision, torchaudio
# Successfully installed dataclasses-0.8 torch-1.8.1+cu102 torchaudio-0.8.1 torchvision-0.9.1+cu102 typing-extensions-4.1.1

# %%
# !cd neural_renderer && python setup.py install --user
# Out:
# running install
# running bdist_egg
# running egg_info
# creating neural_renderer_pytorch.egg-info
# writing neural_renderer_pytorch.egg-info/PKG-INFO
# writing dependency_links to neural_renderer_pytorch.egg-info/dependency_links.txt
# writing top-level names to neural_renderer_pytorch.egg-info/top_level.txt
# writing manifest file 'neural_renderer_pytorch.egg-info/SOURCES.txt'
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/utils/cpp_extension.py:369: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'neural_renderer_pytorch.egg-info/SOURCES.txt'
# writing manifest file 'neural_renderer_pytorch.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.6
# creating build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/vertices_to_faces.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/lighting.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/load_obj.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/projection.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/perspective.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/__init__.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/mesh.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/look.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/save_obj.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/look_at.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/rasterize.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/get_points_from_angles.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/renderer.py -> build/lib.linux-x86_64-3.6/neural_renderer
# creating build/lib.linux-x86_64-3.6/neural_renderer/cuda
# copying neural_renderer/cuda/__init__.py -> build/lib.linux-x86_64-3.6/neural_renderer/cuda
# running build_ext
# building 'neural_renderer.cuda.load_textures' extension
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/neural_renderer
# creating build/temp.linux-x86_64-3.6/neural_renderer/cuda
# gcc -pthread -B /scratch/nv2095/new_env/new_env/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/TH -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/THC -I/share/apps/cuda/10.2.89/include -I/scratch/nv2095/new_env/new_env/include/python3.6m -c neural_renderer/cuda/load_textures_cuda.cpp -o build/temp.linux-x86_64-3.6/neural_renderer/cuda/load_textures_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=load_textures -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# cc1plus: warning: command line option ‘-Wstrict-prototypes’ is valid for C/ObjC but not for C++
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Parallel.h:140,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/utils.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/nn/cloneable.h:5,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/nn.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:13,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ParallelOpenMP.h:83: warning: ignoring #pragma omp parallel [-Wunknown-pragmas]
#  #pragma omp parallel for if ((end - begin) >= grain_size)
#
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# neural_renderer/cuda/load_textures_cuda.cpp: In function ‘at::Tensor load_textures(at::Tensor, at::Tensor, at::Tensor, at::Tensor, int, int)’:
# neural_renderer/cuda/load_textures_cuda.cpp:19:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:19:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:21:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:32:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(image);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# neural_renderer/cuda/load_textures_cuda.cpp:19:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:19:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:21:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:33:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(faces);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# neural_renderer/cuda/load_textures_cuda.cpp:19:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:19:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:21:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:34:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(is_update);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# neural_renderer/cuda/load_textures_cuda.cpp:19:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:19:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:21:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:35:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(textures);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# /share/apps/cuda/10.2.89/bin/nvcc -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/TH -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/THC -I/share/apps/cuda/10.2.89/include -I/scratch/nv2095/new_env/new_env/include/python3.6m -c neural_renderer/cuda/load_textures_cuda_kernel.cu -o build/temp.linux-x86_64-3.6/neural_renderer/cuda/load_textures_cuda_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=load_textures -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 -std=c++14
# g++ -pthread -shared -B /scratch/nv2095/new_env/new_env/compiler_compat -L/scratch/nv2095/new_env/new_env/lib -Wl,-rpath=/scratch/nv2095/new_env/new_env/lib -Wl,--no-as-needed -Wl,--sysroot=/ build/temp.linux-x86_64-3.6/neural_renderer/cuda/load_textures_cuda.o build/temp.linux-x86_64-3.6/neural_renderer/cuda/load_textures_cuda_kernel.o -L/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/lib -L/share/apps/cuda/10.2.89/lib64 -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-3.6/neural_renderer/cuda/load_textures.cpython-36m-x86_64-linux-gnu.so
# building 'neural_renderer.cuda.rasterize' extension
# gcc -pthread -B /scratch/nv2095/new_env/new_env/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/TH -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/THC -I/share/apps/cuda/10.2.89/include -I/scratch/nv2095/new_env/new_env/include/python3.6m -c neural_renderer/cuda/rasterize_cuda.cpp -o build/temp.linux-x86_64-3.6/neural_renderer/cuda/rasterize_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=rasterize -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# cc1plus: warning: command line option ‘-Wstrict-prototypes’ is valid for C/ObjC but not for C++
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Parallel.h:140,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/utils.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/nn/cloneable.h:5,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/nn.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:13,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ParallelOpenMP.h:83: warning: ignoring #pragma omp parallel [-Wunknown-pragmas]
#  #pragma omp parallel for if ((end - begin) >= grain_size)
#
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# neural_renderer/cuda/rasterize_cuda.cpp: In function ‘std::vector<at::Tensor> forward_face_index_map(at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor, int, float, float, int, int, int)’:
# neural_renderer/cuda/rasterize_cuda.cpp:70:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:70:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:72:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:88:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(faces);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# neural_renderer/cuda/rasterize_cuda.cpp:70:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:70:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:72:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:89:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(face_index_map);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# neural_renderer/cuda/rasterize_cuda.cpp:70:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:70:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:72:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:90:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(weight_map);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# neural_renderer/cuda/rasterize_cuda.cpp:70:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:70:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:72:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# ...
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:17:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:19:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:29:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(textures);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/create_texture_image_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/create_texture_image_cuda.cpp:1:
# neural_renderer/cuda/create_texture_image_cuda.cpp:17:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:17:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:19:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:30:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(image);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/create_texture_image_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# /share/apps/cuda/10.2.89/bin/nvcc -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/TH -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/THC -I/share/apps/cuda/10.2.89/include -I/scratch/nv2095/new_env/new_env/include/python3.6m -c neural_renderer/cuda/create_texture_image_cuda_kernel.cu -o build/temp.linux-x86_64-3.6/neural_renderer/cuda/create_texture_image_cuda_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=create_texture_image -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 -std=c++14
# g++ -pthread -shared -B /scratch/nv2095/new_env/new_env/compiler_compat -L/scratch/nv2095/new_env/new_env/lib -Wl,-rpath=/scratch/nv2095/new_env/new_env/lib -Wl,--no-as-needed -Wl,--sysroot=/ build/temp.linux-x86_64-3.6/neural_renderer/cuda/create_texture_image_cuda.o build/temp.linux-x86_64-3.6/neural_renderer/cuda/create_texture_image_cuda_kernel.o -L/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/lib -L/share/apps/cuda/10.2.89/lib64 -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-3.6/neural_renderer/cuda/create_texture_image.cpython-36m-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/vertices_to_faces.py -> build/bdist.linux-x86_64/egg/neural_renderer
# creating build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.6/neural_renderer/cuda/__init__.py -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.6/neural_renderer/cuda/create_texture_image.cpython-36m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.6/neural_renderer/cuda/load_textures.cpython-36m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.6/neural_renderer/cuda/rasterize.cpython-36m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.6/neural_renderer/lighting.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/load_obj.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/projection.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/perspective.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/__init__.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/mesh.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/look.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/save_obj.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/look_at.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/rasterize.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/get_points_from_angles.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/renderer.py -> build/bdist.linux-x86_64/egg/neural_renderer
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/vertices_to_faces.py to vertices_to_faces.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/lighting.py to lighting.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/load_obj.py to load_obj.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/projection.py to projection.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/perspective.py to perspective.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/mesh.py to mesh.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/look.py to look.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/save_obj.py to save_obj.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/look_at.py to look_at.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/rasterize.py to rasterize.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/get_points_from_angles.py to get_points_from_angles.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/renderer.py to renderer.cpython-36.pyc
# creating stub loader for neural_renderer/cuda/load_textures.cpython-36m-x86_64-linux-gnu.so
# creating stub loader for neural_renderer/cuda/rasterize.cpython-36m-x86_64-linux-gnu.so
# creating stub loader for neural_renderer/cuda/create_texture_image.cpython-36m-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/load_textures.py to load_textures.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/rasterize.py to rasterize.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/create_texture_image.py to create_texture_image.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# neural_renderer.cuda.__pycache__.create_texture_image.cpython-36: module references __file__
# neural_renderer.cuda.__pycache__.load_textures.cpython-36: module references __file__
# neural_renderer.cuda.__pycache__.rasterize.cpython-36: module references __file__
# creating dist
# creating 'dist/neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg
# removing '/home/nv2095/.local/lib/python3.6/site-packages/neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg' (and everything under it)
# creating /home/nv2095/.local/lib/python3.6/site-packages/neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg
# Extracting neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg to /home/nv2095/.local/lib/python3.6/site-packages
# neural-renderer-pytorch 1.1.3 is already the active version in easy-install.pth
#
# Installed /home/nv2095/.local/lib/python3.6/site-packages/neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg
# Processing dependencies for neural-renderer-pytorch==1.1.3
# Finished processing dependencies for neural-renderer-pytorch==1.1.3

# %%
# !pip install ipykernel
# Out:
# Collecting ipykernel
#   Downloading ipykernel-5.5.6-py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 32.7 MB/s eta 0:00:01
# Collecting traitlets>=4.1.0
#   Downloading traitlets-4.3.3-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 5.9 MB/s s eta 0:00:01
# Collecting tornado>=4.2
#   Downloading tornado-6.1-cp36-cp36m-manylinux2010_x86_64.whl (427 kB)
#      |████████████████████████████████| 427 kB 150.1 MB/s eta 0:00:01
# Collecting ipython>=5.0.0
#   Downloading ipython-7.16.3-py3-none-any.whl (783 kB)
#      |████████████████████████████████| 783 kB 112.8 MB/s eta 0:00:01
# Collecting jupyter-client
#   Downloading jupyter_client-7.1.2-py3-none-any.whl (130 kB)
#      |████████████████████████████████| 130 kB 153.4 MB/s eta 0:00:01
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Requirement already satisfied: decorator in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (4.4.2)
# Collecting jedi<=0.17.2,>=0.10
#   Downloading jedi-0.17.2-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 144.4 MB/s eta 0:00:01
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.29-py3-none-any.whl (381 kB)
#      |████████████████████████████████| 381 kB 147.2 MB/s eta 0:00:01
# Collecting pexpect
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 2.2 MB/s s eta 0:00:01
# Requirement already satisfied: setuptools>=18.5 in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (58.0.4)
# Collecting pygments
#   Downloading Pygments-2.12.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 143.4 MB/s eta 0:00:01
# Collecting parso<0.8.0,>=0.7.0
#   Downloading parso-0.7.1-py2.py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 152.4 MB/s eta 0:00:01
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: six in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from traitlets>=4.1.0->ipykernel) (1.16.0)
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: python-dateutil>=2.1 in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from jupyter-client->ipykernel) (2.8.2)
# Collecting pyzmq>=13
#   Downloading pyzmq-22.3.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 137.7 MB/s eta 0:00:01
# Collecting jupyter-core>=4.6.0
#   Downloading jupyter_core-4.9.2-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 8.7 MB/s s eta 0:00:01
# Collecting nest-asyncio>=1.5
#   Downloading nest_asyncio-1.5.5-py3-none-any.whl (5.2 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Installing collected packages: ipython-genutils, wcwidth, traitlets, ptyprocess, parso, tornado, pyzmq, pygments, prompt-toolkit, pickleshare, pexpect, nest-asyncio, jupyter-core, jedi, entrypoints, backcall, jupyter-client, ipython, ipykernel
# Successfully installed backcall-0.2.0 entrypoints-0.4 ipykernel-5.5.6 ipython-7.16.3 ipython-genutils-0.2.0 jedi-0.17.2 jupyter-client-7.1.2 jupyter-core-4.9.2 nest-asyncio-1.5.5 parso-0.7.1 pexpect-4.8.0 pickleshare-0.7.5 prompt-toolkit-3.0.29 ptyprocess-0.7.0 pygments-2.12.0 pyzmq-22.3.0 tornado-6.1 traitlets-4.3.3 wcwidth-0.2.5

# %%
# !python neural_renderer/test2.py
# Out:
# Traceback (most recent call last):
#   File "neural_renderer/test2.py", line 1, in <module>
#     from neural_renderer import *
#   File "/scratch/nv2095/new_project/3DStyleTransfer/style_transfer/src/neural_renderer/neural_renderer/__init__.py", line 3, in <module>
#     from .load_obj import load_obj
#   File "/scratch/nv2095/new_project/3DStyleTransfer/style_transfer/src/neural_renderer/neural_renderer/load_obj.py", line 8, in <module>
#     import neural_renderer.cuda.load_textures as load_textures_cuda
# ModuleNotFoundError: No module named 'neural_renderer.cuda.load_textures'

# %%
# !cd scripts/ && ls && bash ./run.sh
# Out:
# data  run.sh
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/scratch/nv2095/new_project/3DStyleTransfer/style_transfer/src/main/StyleLoss.py:50: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /scratch/nv2095/new_project/3DStyleTransfer/style_transfer/src/main/StyleLoss.py:51: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# Optimizing. Loss 668803.5000: 100%|███████████| 100/100 [00:19<00:00,  5.24it/s]
# Saving the object after performing style tra
# Drawing:   0%|                                           | 0/90 [00:00<?, ?it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0000.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05488473176956177, 0.06177343800663948]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   1%|▍                                  | 1/90 [00:00<00:18,  4.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0001.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05474897846579552, 0.06440457701683044]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   1%|▍                                  | 1/90 [00:00<00:18,  4.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0002.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05419890955090523, 0.061516571789979935]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   1%|▍                                  | 1/90 [00:00<00:18,  4.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0003.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05502215400338173, 0.06309527158737183]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   1%|▍                                  | 1/90 [00:00<00:18,  4.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0004.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05483727902173996, 0.0633334070444107]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   6%|█▉                                 | 5/90 [00:00<00:04, 17.01it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0005.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05470491573214531, 0.0595940500497818]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   6%|█▉                                 | 5/90 [00:00<00:04, 17.01it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0006.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05459953844547272, 0.061721574515104294]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   6%|█▉                                 | 5/90 [00:00<00:04, 17.01it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0007.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.054600074887275696, 0.059797074645757675]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   6%|█▉                                 | 5/90 [00:00<00:04, 17.01it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0008.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05476459115743637, 0.06190454214811325]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  10%|███▌                               | 9/90 [00:00<00:03, 22.74it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0009.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05496443435549736, 0.06320412456989288]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  10%|███▌                               | 9/90 [00:00<00:03, 22.74it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0010.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.055633388459682465, 0.06376896053552628]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  10%|███▌                               | 9/90 [00:00<00:03, 22.74it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0011.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05567668378353119, 0.06361517310142517]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  10%|███▌                               | 9/90 [00:00<00:03, 22.74it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0012.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05564676225185394, 0.06269483268260956]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  14%|████▉                             | 13/90 [00:00<00:02, 26.58it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0013.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05566505342721939, 0.06516942381858826]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  14%|████▉                             | 13/90 [00:00<00:02, 26.58it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0014.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05507928878068924, 0.06256598234176636]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  14%|████▉                             | 13/90 [00:00<00:02, 26.58it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0015.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05535881221294403, 0.0631088837981224]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  14%|████▉                             | 13/90 [00:00<00:02, 26.58it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0016.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05557016283273697, 0.062381621450185776]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  19%|██████▍                           | 17/90 [00:00<00:02, 29.22it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0017.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.055431902408599854, 0.05998051166534424]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  19%|██████▍                           | 17/90 [00:00<00:02, 29.22it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0018.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05495595186948776, 0.06193293631076813]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  19%|██████▍                           | 17/90 [00:00<00:02, 29.22it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0019.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05545751750469208, 0.06062666326761246]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  19%|██████▍                           | 17/90 [00:00<00:02, 29.22it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0020.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.055908799171447754, 0.05931185185909271]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  23%|███████▉                          | 21/90 [00:00<00:02, 31.20it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0021.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05543489009141922, 0.05834196135401726]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  23%|███████▉                          | 21/90 [00:00<00:02, 31.20it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0022.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05503552407026291, 0.058609526604413986]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  23%|███████▉                          | 21/90 [00:00<00:02, 31.20it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0023.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.054919369518756866, 0.05790449678897858]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  23%|███████▉                          | 21/90 [00:00<00:02, 31.20it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0024.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05553207919001579, 0.057215139269828796]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  28%|█████████▍                        | 25/90 [00:00<00:01, 32.82it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0025.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05597944185137749, 0.057943571358919144]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  28%|█████████▍                        | 25/90 [00:00<00:01, 32.82it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0026.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05465073138475418, 0.05777769535779953]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  28%|█████████▍                        | 25/90 [00:00<00:01, 32.82it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0027.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05568694323301315, 0.05803905799984932]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  28%|█████████▍                        | 25/90 [00:00<00:01, 32.82it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0028.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05488061532378197, 0.05456436052918434]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  32%|██████████▉                       | 29/90 [00:01<00:01, 34.26it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0029.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05540395528078079, 0.05728446692228317]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  32%|██████████▉                       | 29/90 [00:01<00:01, 34.26it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0030.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05525827407836914, 0.05436279624700546]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  32%|██████████▉                       | 29/90 [00:01<00:01, 34.26it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0031.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.055242784321308136, 0.05423493683338165]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  32%|██████████▉                       | 29/90 [00:01<00:01, 34.26it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0032.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05473877117037773, 0.05441617965698242]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  37%|████████████▍                     | 33/90 [00:01<00:01, 35.37it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0033.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05518294870853424, 0.05419577658176422]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  37%|████████████▍                     | 33/90 [00:01<00:01, 35.37it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0034.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05430757254362106, 0.05412738770246506]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  37%|████████████▍                     | 33/90 [00:01<00:01, 35.37it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0035.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05518493056297302, 0.054492801427841187]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  37%|████████████▍                     | 33/90 [00:01<00:01, 35.37it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0036.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.054095808416604996, 0.05357184261083603]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  41%|█████████████▉                    | 37/90 [00:01<00:01, 35.95it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0037.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.054825760424137115, 0.05567546188831329]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  41%|█████████████▉                    | 37/90 [00:01<00:01, 35.95it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0038.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05432021990418434, 0.05468282103538513]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  41%|█████████████▉                    | 37/90 [00:01<00:01, 35.95it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0039.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05383041128516197, 0.05578798055648804]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  41%|█████████████▉                    | 37/90 [00:01<00:01, 35.95it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0040.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.054042961448431015, 0.05440862476825714]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  46%|███████████████▍                  | 41/90 [00:01<00:01, 35.83it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0041.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.053471844643354416, 0.05488484725356102]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  46%|███████████████▍                  | 41/90 [00:01<00:01, 35.83it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0042.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05214862897992134, 0.05546942353248596]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  46%|███████████████▍                  | 41/90 [00:01<00:01, 35.83it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0043.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05054806172847748, 0.05547850579023361]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  46%|███████████████▍                  | 41/90 [00:01<00:01, 35.83it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0044.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.046681106090545654, 0.055067989975214005]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  50%|█████████████████                 | 45/90 [00:01<00:01, 35.59it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0045.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04490499943494797, 0.054875485599040985]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  50%|█████████████████                 | 45/90 [00:01<00:01, 35.59it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0046.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.043151482939720154, 0.055440835654735565]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  50%|█████████████████                 | 45/90 [00:01<00:01, 35.59it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0047.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04142528772354126, 0.055516667664051056]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  50%|█████████████████                 | 45/90 [00:01<00:01, 35.59it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0048.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04360753670334816, 0.05492392182350159]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  54%|██████████████████▌               | 49/90 [00:01<00:01, 35.45it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0049.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.039945341646671295, 0.055031824856996536]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  54%|██████████████████▌               | 49/90 [00:01<00:01, 35.45it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0050.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.03842923790216446, 0.05515524744987488]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  54%|██████████████████▌               | 49/90 [00:01<00:01, 35.45it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0051.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.040262408554553986, 0.05431244522333145]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  54%|██████████████████▌               | 49/90 [00:01<00:01, 35.45it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0052.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.038799919188022614, 0.054717935621738434]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  59%|████████████████████              | 53/90 [00:01<00:01, 35.23it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0053.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04182291775941849, 0.05502263456583023]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  59%|████████████████████              | 53/90 [00:01<00:01, 35.23it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0054.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.03865594416856766, 0.05572748929262161]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  59%|████████████████████              | 53/90 [00:01<00:01, 35.23it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0055.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.03911161050200462, 0.054860010743141174]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  59%|████████████████████              | 53/90 [00:01<00:01, 35.23it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0056.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.03893505781888962, 0.05348777398467064]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  63%|█████████████████████▌            | 57/90 [00:01<00:00, 35.15it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0057.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.038158856332302094, 0.05332280322909355]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  63%|█████████████████████▌            | 57/90 [00:01<00:00, 35.15it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0058.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.039979834109544754, 0.054754745215177536]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  63%|█████████████████████▌            | 57/90 [00:01<00:00, 35.15it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0059.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.038203708827495575, 0.05481095239520073]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  63%|█████████████████████▌            | 57/90 [00:01<00:00, 35.15it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0060.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.038446445018053055, 0.05337245389819145]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  68%|███████████████████████           | 61/90 [00:01<00:00, 35.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0061.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04116500914096832, 0.054984547197818756]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  68%|███████████████████████           | 61/90 [00:01<00:00, 35.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0062.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.03938810154795647, 0.05358060076832771]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  68%|███████████████████████           | 61/90 [00:01<00:00, 35.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0063.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.041013021022081375, 0.053396932780742645]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  68%|███████████████████████           | 61/90 [00:02<00:00, 35.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0064.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04124601185321808, 0.05534059554338455]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  72%|████████████████████████▌         | 65/90 [00:02<00:00, 35.35it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0065.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.039840273559093475, 0.05578022450208664]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  72%|████████████████████████▌         | 65/90 [00:02<00:00, 35.35it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0066.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.0402962863445282, 0.05804114788770676]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  72%|████████████████████████▌         | 65/90 [00:02<00:00, 35.35it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0067.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.042222194373607635, 0.05872723087668419]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  72%|████████████████████████▌         | 65/90 [00:02<00:00, 35.35it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0068.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04157523810863495, 0.05823717266321182]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  77%|██████████████████████████        | 69/90 [00:02<00:00, 35.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0069.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04399894177913666, 0.05906035006046295]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  77%|██████████████████████████        | 69/90 [00:02<00:00, 35.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0070.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04173785820603371, 0.059412065893411636]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  77%|██████████████████████████        | 69/90 [00:02<00:00, 35.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0071.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04543773829936981, 0.06019769236445427]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  77%|██████████████████████████        | 69/90 [00:02<00:00, 35.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0072.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04314500465989113, 0.05944576486945152]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  81%|███████████████████████████▌      | 73/90 [00:02<00:00, 35.01it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0073.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04624263197183609, 0.05997844785451889]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  81%|███████████████████████████▌      | 73/90 [00:02<00:00, 35.01it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0074.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04459921643137932, 0.0599948987364769]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  81%|███████████████████████████▌      | 73/90 [00:02<00:00, 35.01it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0075.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04677483066916466, 0.05991552025079727]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  81%|███████████████████████████▌      | 73/90 [00:02<00:00, 35.01it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0076.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.043506719172000885, 0.05992914363741875]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  86%|█████████████████████████████     | 77/90 [00:02<00:00, 34.88it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0077.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04330785945057869, 0.060168780386447906]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  86%|█████████████████████████████     | 77/90 [00:02<00:00, 34.88it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0078.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04708399623632431, 0.0600397028028965]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  86%|█████████████████████████████     | 77/90 [00:02<00:00, 34.88it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0079.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.043455008417367935, 0.0597672313451767]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  86%|█████████████████████████████     | 77/90 [00:02<00:00, 34.88it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0080.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04261895641684532, 0.05871987342834473]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  90%|██████████████████████████████▌   | 81/90 [00:02<00:00, 34.52it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0081.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04403631389141083, 0.060374848544597626]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  90%|██████████████████████████████▌   | 81/90 [00:02<00:00, 34.52it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0082.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.043414972722530365, 0.06036955863237381]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  90%|██████████████████████████████▌   | 81/90 [00:02<00:00, 34.52it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0083.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.043294116854667664, 0.059913359582424164]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  90%|██████████████████████████████▌   | 81/90 [00:02<00:00, 34.52it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0084.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04495645686984062, 0.06121615692973137]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  94%|████████████████████████████████  | 85/90 [00:02<00:00, 33.89it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0085.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.04922725632786751, 0.05968885496258736]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  94%|████████████████████████████████  | 85/90 [00:02<00:00, 33.89it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0086.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.051346488296985626, 0.05950995907187462]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  94%|████████████████████████████████  | 85/90 [00:02<00:00, 33.89it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0087.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.052959345281124115, 0.06027550995349884]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  94%|████████████████████████████████  | 85/90 [00:02<00:00, 33.89it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0088.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.051834508776664734, 0.05975344032049179]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  99%|█████████████████████████████████▌| 89/90 [00:02<00:00, 32.95it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0089.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.05383217707276344, 0.059687793254852295]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing: 100%|██████████████████████████████████| 90/90 [00:02<00:00, 32.33it/s]
# Saving the object after style transfer.
# the file name is ./data/results/stylized_teapot.obj
# /home/nv2095/.local/lib/python3.6/site-packages/neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg/neural_renderer/save_obj.py:50: UserWarning: ./data/results/stylized_teapot.png is a low contrast image
#   imsave(filename_texture, texture_image)
# Lossy conversion from float32 to uint8. Range [-0.057446882128715515, 0.062173712998628616]. Convert image to uint8 prior to saving to suppress this warning.
# Generating texture mapping for the generated stylized object.
# Optimizing: 100%|█████████████████████████████| 300/300 [00:27<00:00, 10.86it/s]
# Drawing:   0%|                                           | 0/90 [00:00<?, ?it/s]Lossy conversion from float32 to uint8. Range [-0.34805798530578613, 0.9741058349609375]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   1%|▍                                  | 1/90 [00:00<00:12,  7.03it/s]Lossy conversion from float32 to uint8. Range [-0.28800320625305176, 0.9753639698028564]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   1%|▍                                  | 1/90 [00:00<00:12,  7.03it/s]Lossy conversion from float32 to uint8. Range [-0.32448333501815796, 0.9734898805618286]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   1%|▍                                  | 1/90 [00:00<00:12,  7.03it/s]Lossy conversion from float32 to uint8. Range [-0.36170583963394165, 0.9746789932250977]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   4%|█▌                                 | 4/90 [00:00<00:05, 15.09it/s]Lossy conversion from float32 to uint8. Range [-0.32143908739089966, 0.975257933139801]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   4%|█▌                                 | 4/90 [00:00<00:05, 15.09it/s]Lossy conversion from float32 to uint8. Range [-0.30646130442619324, 0.9749405384063721]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   4%|█▌                                 | 4/90 [00:00<00:05, 15.09it/s]Lossy conversion from float32 to uint8. Range [-0.3064386248588562, 0.9750405550003052]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   8%|██▋                                | 7/90 [00:00<00:04, 18.03it/s]Lossy conversion from float32 to uint8. Range [-0.33116623759269714, 0.9747430682182312]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   8%|██▋                                | 7/90 [00:00<00:04, 18.03it/s]Lossy conversion from float32 to uint8. Range [-0.2596163749694824, 0.9756230115890503]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   8%|██▋                                | 7/90 [00:00<00:04, 18.03it/s]Lossy conversion from float32 to uint8. Range [-0.24580690264701843, 0.9748806357383728]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  11%|███▊                              | 10/90 [00:00<00:04, 19.88it/s]Lossy conversion from float32 to uint8. Range [-0.2317228615283966, 0.9832730889320374]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  11%|███▊                              | 10/90 [00:00<00:04, 19.88it/s]Lossy conversion from float32 to uint8. Range [-0.2542431354522705, 0.9739464521408081]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  11%|███▊                              | 10/90 [00:00<00:04, 19.88it/s]Lossy conversion from float32 to uint8. Range [-0.24024073779582977, 0.9750639796257019]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  14%|████▉                             | 13/90 [00:00<00:03, 21.71it/s]Lossy conversion from float32 to uint8. Range [-0.21068690717220306, 0.976302981376648]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  14%|████▉                             | 13/90 [00:00<00:03, 21.71it/s]Lossy conversion from float32 to uint8. Range [-0.2351377308368683, 0.9820433855056763]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  14%|████▉                             | 13/90 [00:00<00:03, 21.71it/s]Lossy conversion from float32 to uint8. Range [-0.22998499870300293, 0.9830036759376526]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  18%|██████                            | 16/90 [00:00<00:03, 23.47it/s]Lossy conversion from float32 to uint8. Range [-0.22682370245456696, 0.9825985431671143]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  18%|██████                            | 16/90 [00:00<00:03, 23.47it/s]Lossy conversion from float32 to uint8. Range [-0.20544949173927307, 0.9904724359512329]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  18%|██████                            | 16/90 [00:00<00:03, 23.47it/s]Lossy conversion from float32 to uint8. Range [-0.22371995449066162, 0.9718617796897888]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  21%|███████▏                          | 19/90 [00:00<00:02, 25.22it/s]Lossy conversion from float32 to uint8. Range [-0.33284080028533936, 0.9736155271530151]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  21%|███████▏                          | 19/90 [00:00<00:02, 25.22it/s]Lossy conversion from float32 to uint8. Range [-0.25871649384498596, 0.9751332998275757]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  21%|███████▏                          | 19/90 [00:00<00:02, 25.22it/s]Lossy conversion from float32 to uint8. Range [-0.3313554525375366, 0.9743878841400146]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  24%|████████▎                         | 22/90 [00:00<00:02, 26.25it/s]Lossy conversion from float32 to uint8. Range [-0.3309563398361206, 0.9725733995437622]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  24%|████████▎                         | 22/90 [00:01<00:02, 26.25it/s]Lossy conversion from float32 to uint8. Range [-0.3314133882522583, 0.9726117849349976]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  24%|████████▎                         | 22/90 [00:01<00:02, 26.25it/s]Lossy conversion from float32 to uint8. Range [-0.3252374529838562, 0.9736332893371582]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  28%|█████████▍                        | 25/90 [00:01<00:02, 26.80it/s]Lossy conversion from float32 to uint8. Range [-0.27632516622543335, 0.9712777137756348]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  28%|█████████▍                        | 25/90 [00:01<00:02, 26.80it/s]Lossy conversion from float32 to uint8. Range [-0.3364237844944, 0.9720112681388855]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  28%|█████████▍                        | 25/90 [00:01<00:02, 26.80it/s]Lossy conversion from float32 to uint8. Range [-0.3113963305950165, 0.9720104932785034]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  31%|██████████▌                       | 28/90 [00:01<00:02, 27.34it/s]Lossy conversion from float32 to uint8. Range [-0.377004474401474, 0.9677009582519531]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  31%|██████████▌                       | 28/90 [00:01<00:02, 27.34it/s]Lossy conversion from float32 to uint8. Range [-0.30063295364379883, 0.9726955890655518]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  31%|██████████▌                       | 28/90 [00:01<00:02, 27.34it/s]Lossy conversion from float32 to uint8. Range [-0.2675148844718933, 0.970385730266571]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  34%|███████████▋                      | 31/90 [00:01<00:02, 27.76it/s]Lossy conversion from float32 to uint8. Range [-0.2684716284275055, 0.9739729762077332]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  34%|███████████▋                      | 31/90 [00:01<00:02, 27.76it/s]Lossy conversion from float32 to uint8. Range [-0.2689835727214813, 0.9781200885772705]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  34%|███████████▋                      | 31/90 [00:01<00:02, 27.76it/s]Lossy conversion from float32 to uint8. Range [-0.2696743607521057, 0.975452721118927]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  38%|████████████▊                     | 34/90 [00:01<00:02, 27.70it/s]Lossy conversion from float32 to uint8. Range [-0.26930660009384155, 0.9786170125007629]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  38%|████████████▊                     | 34/90 [00:01<00:02, 27.70it/s]Lossy conversion from float32 to uint8. Range [-0.26995062828063965, 0.9740018844604492]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  38%|████████████▊                     | 34/90 [00:01<00:02, 27.70it/s]Lossy conversion from float32 to uint8. Range [-0.3711318075656891, 0.9767478704452515]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  41%|█████████████▉                    | 37/90 [00:01<00:01, 27.12it/s]Lossy conversion from float32 to uint8. Range [-0.38839420676231384, 0.9782060384750366]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  41%|█████████████▉                    | 37/90 [00:01<00:01, 27.12it/s]Lossy conversion from float32 to uint8. Range [-0.3618737459182739, 0.9759404063224792]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  41%|█████████████▉                    | 37/90 [00:01<00:01, 27.12it/s]Lossy conversion from float32 to uint8. Range [-0.48634642362594604, 0.9768847227096558]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  44%|███████████████                   | 40/90 [00:01<00:01, 25.81it/s]Lossy conversion from float32 to uint8. Range [-0.31400081515312195, 0.9767215847969055]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  44%|███████████████                   | 40/90 [00:01<00:01, 25.81it/s]Lossy conversion from float32 to uint8. Range [-0.28287333250045776, 0.9809204339981079]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  44%|███████████████                   | 40/90 [00:01<00:01, 25.81it/s]Lossy conversion from float32 to uint8. Range [-0.2760659158229828, 0.9710990786552429]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  48%|████████████████▏                 | 43/90 [00:01<00:01, 25.17it/s]Lossy conversion from float32 to uint8. Range [-0.26829540729522705, 0.9719492793083191]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  48%|████████████████▏                 | 43/90 [00:01<00:01, 25.17it/s]Lossy conversion from float32 to uint8. Range [-0.27675294876098633, 0.9782677888870239]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  48%|████████████████▏                 | 43/90 [00:01<00:01, 25.17it/s]Lossy conversion from float32 to uint8. Range [-0.28456589579582214, 0.979427695274353]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  51%|█████████████████▍                | 46/90 [00:01<00:01, 24.45it/s]Lossy conversion from float32 to uint8. Range [-0.2683153748512268, 0.9757813215255737]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  51%|█████████████████▍                | 46/90 [00:01<00:01, 24.45it/s]Lossy conversion from float32 to uint8. Range [-0.2684530019760132, 0.978767454624176]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  51%|█████████████████▍                | 46/90 [00:02<00:01, 24.45it/s]Lossy conversion from float32 to uint8. Range [-0.38340866565704346, 0.9780567288398743]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  54%|██████████████████▌               | 49/90 [00:02<00:01, 23.85it/s]Lossy conversion from float32 to uint8. Range [-0.3922474980354309, 0.9730852246284485]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  54%|██████████████████▌               | 49/90 [00:02<00:01, 23.85it/s]Lossy conversion from float32 to uint8. Range [-0.31725355982780457, 0.9738137722015381]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  54%|██████████████████▌               | 49/90 [00:02<00:01, 23.85it/s]Lossy conversion from float32 to uint8. Range [-0.27019035816192627, 0.973126232624054]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  58%|███████████████████▋              | 52/90 [00:02<00:01, 23.83it/s]Lossy conversion from float32 to uint8. Range [-0.28842514753341675, 0.9713937640190125]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  58%|███████████████████▋              | 52/90 [00:02<00:01, 23.83it/s]Lossy conversion from float32 to uint8. Range [-0.2876722812652588, 0.9725626111030579]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  58%|███████████████████▋              | 52/90 [00:02<00:01, 23.83it/s]Lossy conversion from float32 to uint8. Range [-0.28819164633750916, 0.9733723998069763]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  61%|████████████████████▊             | 55/90 [00:02<00:01, 24.15it/s]Lossy conversion from float32 to uint8. Range [-0.2692318856716156, 0.9727320671081543]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  61%|████████████████████▊             | 55/90 [00:02<00:01, 24.15it/s]Lossy conversion from float32 to uint8. Range [-0.33707940578460693, 0.9685160517692566]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  61%|████████████████████▊             | 55/90 [00:02<00:01, 24.15it/s]Lossy conversion from float32 to uint8. Range [-0.35437649488449097, 0.9700213670730591]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  64%|█████████████████████▉            | 58/90 [00:02<00:01, 24.53it/s]Lossy conversion from float32 to uint8. Range [-0.6116213202476501, 0.9678248167037964]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  64%|█████████████████████▉            | 58/90 [00:02<00:01, 24.53it/s]Lossy conversion from float32 to uint8. Range [-0.38738009333610535, 0.9677497744560242]. Convert image to uint8 prior to saving to suppress this warning.
# ...
# Drawing:  24%|████████▎                         | 22/90 [00:01<00:02, 24.93it/s]Lossy conversion from float32 to uint8. Range [-0.2146199345588684, 0.8765794634819031]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  28%|█████████▍                        | 25/90 [00:01<00:02, 25.70it/s]Lossy conversion from float32 to uint8. Range [-0.21195216476917267, 0.8556537628173828]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  28%|█████████▍                        | 25/90 [00:01<00:02, 25.70it/s]Lossy conversion from float32 to uint8. Range [-0.19710783660411835, 0.8113176822662354]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  28%|█████████▍                        | 25/90 [00:01<00:02, 25.70it/s]Lossy conversion from float32 to uint8. Range [-0.3623049855232239, 0.8055130243301392]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  31%|██████████▌                       | 28/90 [00:01<00:02, 26.22it/s]Lossy conversion from float32 to uint8. Range [-0.20063087344169617, 0.7989757061004639]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  31%|██████████▌                       | 28/90 [00:01<00:02, 26.22it/s]Lossy conversion from float32 to uint8. Range [-0.23131971061229706, 0.8073050379753113]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  31%|██████████▌                       | 28/90 [00:01<00:02, 26.22it/s]Lossy conversion from float32 to uint8. Range [-0.21472828090190887, 0.8138728737831116]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  34%|███████████▋                      | 31/90 [00:01<00:02, 26.71it/s]Lossy conversion from float32 to uint8. Range [-0.20333071053028107, 0.8519395589828491]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  34%|███████████▋                      | 31/90 [00:01<00:02, 26.71it/s]Lossy conversion from float32 to uint8. Range [-0.22144092619419098, 0.7918620109558105]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  34%|███████████▋                      | 31/90 [00:01<00:02, 26.71it/s]Lossy conversion from float32 to uint8. Range [-0.22637993097305298, 0.7985427379608154]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  38%|████████████▊                     | 34/90 [00:01<00:02, 27.07it/s]Lossy conversion from float32 to uint8. Range [-0.21572135388851166, 0.8191836476325989]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  38%|████████████▊                     | 34/90 [00:01<00:02, 27.07it/s]Lossy conversion from float32 to uint8. Range [-0.24687132239341736, 0.8142244815826416]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  38%|████████████▊                     | 34/90 [00:01<00:02, 27.07it/s]Lossy conversion from float32 to uint8. Range [-0.20802167057991028, 0.835789680480957]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  41%|█████████████▉                    | 37/90 [00:01<00:01, 27.24it/s]Lossy conversion from float32 to uint8. Range [-0.2102058082818985, 0.839429497718811]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  41%|█████████████▉                    | 37/90 [00:01<00:01, 27.24it/s]Lossy conversion from float32 to uint8. Range [-0.20507276058197021, 0.8318806886672974]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  41%|█████████████▉                    | 37/90 [00:01<00:01, 27.24it/s]Lossy conversion from float32 to uint8. Range [-0.23746737837791443, 0.8376270532608032]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  44%|███████████████                   | 40/90 [00:01<00:01, 27.17it/s]Lossy conversion from float32 to uint8. Range [-0.21270690858364105, 0.8694284558296204]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  44%|███████████████                   | 40/90 [00:01<00:01, 27.17it/s]Lossy conversion from float32 to uint8. Range [-0.23360316455364227, 0.865873396396637]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  44%|███████████████                   | 40/90 [00:01<00:01, 27.17it/s]Lossy conversion from float32 to uint8. Range [-0.2744055986404419, 0.8585163950920105]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  48%|████████████████▏                 | 43/90 [00:01<00:01, 26.79it/s]Lossy conversion from float32 to uint8. Range [-0.2679074704647064, 0.8369949460029602]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  48%|████████████████▏                 | 43/90 [00:01<00:01, 26.79it/s]Lossy conversion from float32 to uint8. Range [-0.27851447463035583, 0.8136337399482727]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  48%|████████████████▏                 | 43/90 [00:01<00:01, 26.79it/s]Lossy conversion from float32 to uint8. Range [-0.23118814826011658, 0.8595482707023621]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  51%|█████████████████▍                | 46/90 [00:01<00:01, 26.44it/s]Lossy conversion from float32 to uint8. Range [-0.2468782365322113, 0.8601952195167542]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  51%|█████████████████▍                | 46/90 [00:01<00:01, 26.44it/s]Lossy conversion from float32 to uint8. Range [-0.21648266911506653, 0.8097577095031738]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  51%|█████████████████▍                | 46/90 [00:01<00:01, 26.44it/s]Lossy conversion from float32 to uint8. Range [-0.23040151596069336, 0.8070694208145142]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  54%|██████████████████▌               | 49/90 [00:01<00:01, 26.30it/s]Lossy conversion from float32 to uint8. Range [-0.2401459515094757, 0.8393523693084717]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  54%|██████████████████▌               | 49/90 [00:02<00:01, 26.30it/s]Lossy conversion from float32 to uint8. Range [-0.21660470962524414, 0.8213726282119751]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  54%|██████████████████▌               | 49/90 [00:02<00:01, 26.30it/s]Lossy conversion from float32 to uint8. Range [-0.20090459287166595, 0.79497230052948]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  58%|███████████████████▋              | 52/90 [00:02<00:01, 26.30it/s]Lossy conversion from float32 to uint8. Range [-0.23095807433128357, 0.8331928253173828]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  58%|███████████████████▋              | 52/90 [00:02<00:01, 26.30it/s]Lossy conversion from float32 to uint8. Range [-0.1974511295557022, 0.8099462985992432]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  58%|███████████████████▋              | 52/90 [00:02<00:01, 26.30it/s]Lossy conversion from float32 to uint8. Range [-0.21675188839435577, 0.8206181526184082]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  61%|████████████████████▊             | 55/90 [00:02<00:01, 26.25it/s]Lossy conversion from float32 to uint8. Range [-0.19010841846466064, 0.8556481599807739]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  61%|████████████████████▊             | 55/90 [00:02<00:01, 26.25it/s]Lossy conversion from float32 to uint8. Range [-0.2971991002559662, 0.8173335790634155]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  61%|████████████████████▊             | 55/90 [00:02<00:01, 26.25it/s]Lossy conversion from float32 to uint8. Range [-0.33532071113586426, 0.8234865665435791]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  64%|█████████████████████▉            | 58/90 [00:02<00:01, 26.21it/s]Lossy conversion from float32 to uint8. Range [-0.6088720560073853, 0.8199365139007568]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  64%|█████████████████████▉            | 58/90 [00:02<00:01, 26.21it/s]Lossy conversion from float32 to uint8. Range [-0.258319228887558, 0.8387753963470459]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  64%|█████████████████████▉            | 58/90 [00:02<00:01, 26.21it/s]Lossy conversion from float32 to uint8. Range [-0.17182940244674683, 0.8285010457038879]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  68%|███████████████████████           | 61/90 [00:02<00:01, 26.07it/s]Lossy conversion from float32 to uint8. Range [-0.3413046896457672, 0.8135796189308167]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  68%|███████████████████████           | 61/90 [00:02<00:01, 26.07it/s]Lossy conversion from float32 to uint8. Range [-0.16776928305625916, 0.760352373123169]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  68%|███████████████████████           | 61/90 [00:02<00:01, 26.07it/s]Lossy conversion from float32 to uint8. Range [-0.18237364292144775, 0.7648230195045471]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  71%|████████████████████████▏         | 64/90 [00:02<00:00, 26.12it/s]Lossy conversion from float32 to uint8. Range [-0.18342170119285583, 0.7588239908218384]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  71%|████████████████████████▏         | 64/90 [00:02<00:00, 26.12it/s]Lossy conversion from float32 to uint8. Range [-0.16019156575202942, 0.7618966102600098]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  71%|████████████████████████▏         | 64/90 [00:02<00:00, 26.12it/s]Lossy conversion from float32 to uint8. Range [-0.18713489174842834, 0.7813707590103149]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  74%|█████████████████████████▎        | 67/90 [00:02<00:00, 26.24it/s]Lossy conversion from float32 to uint8. Range [-0.22195157408714294, 0.8426784873008728]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  74%|█████████████████████████▎        | 67/90 [00:02<00:00, 26.24it/s]Lossy conversion from float32 to uint8. Range [-0.21263465285301208, 0.8238041400909424]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  74%|█████████████████████████▎        | 67/90 [00:02<00:00, 26.24it/s]Lossy conversion from float32 to uint8. Range [-0.15980489552021027, 0.8074847459793091]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  78%|██████████████████████████▍       | 70/90 [00:02<00:00, 26.07it/s]Lossy conversion from float32 to uint8. Range [-0.18115057051181793, 0.7959514856338501]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  78%|██████████████████████████▍       | 70/90 [00:02<00:00, 26.07it/s]Lossy conversion from float32 to uint8. Range [-0.16336509585380554, 0.7828494906425476]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  78%|██████████████████████████▍       | 70/90 [00:02<00:00, 26.07it/s]Lossy conversion from float32 to uint8. Range [-0.15448138117790222, 0.7875671982765198]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  81%|███████████████████████████▌      | 73/90 [00:02<00:00, 25.91it/s]Lossy conversion from float32 to uint8. Range [-0.20717346668243408, 0.7712509036064148]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  81%|███████████████████████████▌      | 73/90 [00:02<00:00, 25.91it/s]Lossy conversion from float32 to uint8. Range [-0.2583022117614746, 0.7739471197128296]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  81%|███████████████████████████▌      | 73/90 [00:02<00:00, 25.91it/s]Lossy conversion from float32 to uint8. Range [-0.17990995943546295, 0.7407350540161133]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  84%|████████████████████████████▋     | 76/90 [00:03<00:00, 25.58it/s]Lossy conversion from float32 to uint8. Range [-0.20064522325992584, 0.751632809638977]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  84%|████████████████████████████▋     | 76/90 [00:03<00:00, 25.58it/s]Lossy conversion from float32 to uint8. Range [-0.22494810819625854, 0.8024615049362183]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  84%|████████████████████████████▋     | 76/90 [00:03<00:00, 25.58it/s]Lossy conversion from float32 to uint8. Range [-0.21630063652992249, 0.768846333026886]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  88%|█████████████████████████████▊    | 79/90 [00:03<00:00, 25.32it/s]Lossy conversion from float32 to uint8. Range [-0.2301265299320221, 0.8055805563926697]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  88%|█████████████████████████████▊    | 79/90 [00:03<00:00, 25.32it/s]Lossy conversion from float32 to uint8. Range [-0.3395102620124817, 0.7940168380737305]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  88%|█████████████████████████████▊    | 79/90 [00:03<00:00, 25.32it/s]Lossy conversion from float32 to uint8. Range [-0.4009057283401489, 0.7752450704574585]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  91%|██████████████████████████████▉   | 82/90 [00:03<00:00, 24.78it/s]Lossy conversion from float32 to uint8. Range [-0.46930548548698425, 0.7980648279190063]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  91%|██████████████████████████████▉   | 82/90 [00:03<00:00, 24.78it/s]Lossy conversion from float32 to uint8. Range [-0.48591944575309753, 0.7936768531799316]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  91%|██████████████████████████████▉   | 82/90 [00:03<00:00, 24.78it/s]Lossy conversion from float32 to uint8. Range [-0.19767647981643677, 0.7929075956344604]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  94%|████████████████████████████████  | 85/90 [00:03<00:00, 24.20it/s]Lossy conversion from float32 to uint8. Range [-0.19023442268371582, 0.7755951285362244]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  94%|████████████████████████████████  | 85/90 [00:03<00:00, 24.20it/s]Lossy conversion from float32 to uint8. Range [-0.1614139974117279, 0.7762123346328735]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  94%|████████████████████████████████  | 85/90 [00:03<00:00, 24.20it/s]Lossy conversion from float32 to uint8. Range [-0.13232465088367462, 0.7896006107330322]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  98%|█████████████████████████████████▏| 88/90 [00:03<00:00, 23.80it/s]Lossy conversion from float32 to uint8. Range [-0.171885147690773, 0.7978665828704834]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  98%|█████████████████████████████████▏| 88/90 [00:03<00:00, 23.80it/s]Lossy conversion from float32 to uint8. Range [-0.1811869740486145, 0.7890546321868896]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing: 100%|██████████████████████████████████| 90/90 [00:03<00:00, 24.95it/s]
# the file name is ./data/results/stylized_and_textured_bunny.obj
# Lossy conversion from float32 to uint8. Range [-2.8538389205932617, 2.95272159576416]. Convert image to uint8 prior to saving to suppress this warning.
