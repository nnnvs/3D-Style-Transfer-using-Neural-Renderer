# %%
# !pip install -r ../../requirements.txt
# Out:
# Collecting numpy
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
#      |████████████████████████████████| 14.8 MB 76 kB/s s eta 0:00:01
# Collecting scikit-image
#   Downloading scikit_image-0.17.2-cp36-cp36m-manylinux1_x86_64.whl (12.4 MB)
#      |████████████████████████████████| 12.4 MB 63 kB/s s eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 9.8 MB/s  eta 0:00:01
# Collecting imageio
#   Downloading imageio-2.15.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 113.0 MB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.3.4-cp36-cp36m-manylinux1_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 41.4 MB/s eta 0:00:01
# Collecting opencv-python
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      |████████████████████████████████| 60.5 MB 40 kB/s /s eta 0:00:01
# Collecting scipy>=1.0.1
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 43.8 MB/s eta 0:00:01
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 52.2 MB/s eta 0:00:01
# Collecting networkx>=2.0
#   Downloading networkx-2.5.1-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 107.6 MB/s eta 0:00:01
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2020.9.3-py3-none-any.whl (148 kB)
#      |████████████████████████████████| 148 kB 151.3 MB/s eta 0:00:01
# Collecting pillow!=7.1.0,!=7.1.1,>=4.3.0
#   Downloading Pillow-8.4.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 133.2 MB/s eta 0:00:01
# Collecting importlib-resources
#   Downloading importlib_resources-5.4.0-py3-none-any.whl (28 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 139.1 MB/s eta 0:00:01
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 13.7 MB/s  eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting python-dateutil>=2.1
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 147.0 MB/s eta 0:00:01
# Collecting decorator<5,>=4.3
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting six>=1.5
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting zipp>=3.1.0
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Installing collected packages: six, zipp, python-dateutil, pyparsing, pillow, numpy, kiwisolver, decorator, cycler, tifffile, scipy, PyWavelets, networkx, matplotlib, importlib-resources, imageio, tqdm, scikit-image, opencv-python
# Successfully installed PyWavelets-1.1.1 cycler-0.11.0 decorator-4.4.2 imageio-2.15.0 importlib-resources-5.4.0 kiwisolver-1.3.1 matplotlib-3.3.4 networkx-2.5.1 numpy-1.19.5 opencv-python-4.5.5.64 pillow-8.4.0 pyparsing-3.0.9 python-dateutil-2.8.2 scikit-image-0.17.2 scipy-1.5.4 six-1.16.0 tifffile-2020.9.3 tqdm-4.64.0 zipp-3.6.0

# %%
# !pip3 install torch==1.8.1+cu102 torchvision==0.9.1+cu102 torchaudio===0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.8.1+cu102
#   Downloading https://download.pytorch.org/whl/cu102/torch-1.8.1%2Bcu102-cp36-cp36m-linux_x86_64.whl (804.1 MB)
#      |████████████████████████████████| 804.1 MB 31 kB/s  eta 0:00:0101
# Collecting torchvision==0.9.1+cu102
#   Downloading https://download.pytorch.org/whl/cu102/torchvision-0.9.1%2Bcu102-cp36-cp36m-linux_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 15.2 MB/s eta 0:00:01
# Collecting torchaudio===0.8.1
#   Downloading torchaudio-0.8.1-cp36-cp36m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 36.2 MB/s eta 0:00:01
# Collecting typing-extensions
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from torch==1.8.1+cu102) (1.19.5)
# Collecting dataclasses
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Requirement already satisfied: pillow>=4.1.1 in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from torchvision==0.9.1+cu102) (8.4.0)
# Installing collected packages: typing-extensions, dataclasses, torch, torchvision, torchaudio
# Successfully installed dataclasses-0.8 torch-1.8.1+cu102 torchaudio-0.8.1 torchvision-0.9.1+cu102 typing-extensions-4.1.1

# %%
# !cd neural_renderer && python setup.py install --user
# Out:
# running install
# running bdist_egg
# running egg_info
# creating neural_renderer_pytorch.egg-info
# writing neural_renderer_pytorch.egg-info/PKG-INFO
# writing dependency_links to neural_renderer_pytorch.egg-info/dependency_links.txt
# writing top-level names to neural_renderer_pytorch.egg-info/top_level.txt
# writing manifest file 'neural_renderer_pytorch.egg-info/SOURCES.txt'
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/utils/cpp_extension.py:369: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'neural_renderer_pytorch.egg-info/SOURCES.txt'
# writing manifest file 'neural_renderer_pytorch.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.6
# creating build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/vertices_to_faces.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/lighting.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/load_obj.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/projection.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/perspective.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/__init__.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/mesh.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/look.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/save_obj.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/look_at.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/rasterize.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/get_points_from_angles.py -> build/lib.linux-x86_64-3.6/neural_renderer
# copying neural_renderer/renderer.py -> build/lib.linux-x86_64-3.6/neural_renderer
# creating build/lib.linux-x86_64-3.6/neural_renderer/cuda
# copying neural_renderer/cuda/__init__.py -> build/lib.linux-x86_64-3.6/neural_renderer/cuda
# running build_ext
# building 'neural_renderer.cuda.load_textures' extension
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/neural_renderer
# creating build/temp.linux-x86_64-3.6/neural_renderer/cuda
# gcc -pthread -B /scratch/nv2095/new_env/new_env/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/TH -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/THC -I/share/apps/cuda/10.2.89/include -I/scratch/nv2095/new_env/new_env/include/python3.6m -c neural_renderer/cuda/load_textures_cuda.cpp -o build/temp.linux-x86_64-3.6/neural_renderer/cuda/load_textures_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=load_textures -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# cc1plus: warning: command line option ‘-Wstrict-prototypes’ is valid for C/ObjC but not for C++
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Parallel.h:140,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/utils.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/nn/cloneable.h:5,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/nn.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:13,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ParallelOpenMP.h:83: warning: ignoring #pragma omp parallel [-Wunknown-pragmas]
#  #pragma omp parallel for if ((end - begin) >= grain_size)
#
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# neural_renderer/cuda/load_textures_cuda.cpp: In function ‘at::Tensor load_textures(at::Tensor, at::Tensor, at::Tensor, at::Tensor, int, int)’:
# neural_renderer/cuda/load_textures_cuda.cpp:19:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:19:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:21:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:32:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(image);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# neural_renderer/cuda/load_textures_cuda.cpp:19:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:19:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:21:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:33:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(faces);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# neural_renderer/cuda/load_textures_cuda.cpp:19:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:19:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:21:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:34:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(is_update);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# neural_renderer/cuda/load_textures_cuda.cpp:19:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:19:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:21:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/load_textures_cuda.cpp:35:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(textures);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/load_textures_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# /share/apps/cuda/10.2.89/bin/nvcc -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/TH -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/THC -I/share/apps/cuda/10.2.89/include -I/scratch/nv2095/new_env/new_env/include/python3.6m -c neural_renderer/cuda/load_textures_cuda_kernel.cu -o build/temp.linux-x86_64-3.6/neural_renderer/cuda/load_textures_cuda_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=load_textures -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 -std=c++14
# g++ -pthread -shared -B /scratch/nv2095/new_env/new_env/compiler_compat -L/scratch/nv2095/new_env/new_env/lib -Wl,-rpath=/scratch/nv2095/new_env/new_env/lib -Wl,--no-as-needed -Wl,--sysroot=/ build/temp.linux-x86_64-3.6/neural_renderer/cuda/load_textures_cuda.o build/temp.linux-x86_64-3.6/neural_renderer/cuda/load_textures_cuda_kernel.o -L/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/lib -L/share/apps/cuda/10.2.89/lib64 -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-3.6/neural_renderer/cuda/load_textures.cpython-36m-x86_64-linux-gnu.so
# building 'neural_renderer.cuda.rasterize' extension
# gcc -pthread -B /scratch/nv2095/new_env/new_env/compiler_compat -Wl,--sysroot=/ -Wsign-compare -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -fPIC -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/TH -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/THC -I/share/apps/cuda/10.2.89/include -I/scratch/nv2095/new_env/new_env/include/python3.6m -c neural_renderer/cuda/rasterize_cuda.cpp -o build/temp.linux-x86_64-3.6/neural_renderer/cuda/rasterize_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=rasterize -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# cc1plus: warning: command line option ‘-Wstrict-prototypes’ is valid for C/ObjC but not for C++
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Parallel.h:140,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/utils.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/nn/cloneable.h:5,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/nn.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:13,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ParallelOpenMP.h:83: warning: ignoring #pragma omp parallel [-Wunknown-pragmas]
#  #pragma omp parallel for if ((end - begin) >= grain_size)
#
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# neural_renderer/cuda/rasterize_cuda.cpp: In function ‘std::vector<at::Tensor> forward_face_index_map(at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor, int, float, float, int, int, int)’:
# neural_renderer/cuda/rasterize_cuda.cpp:70:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:70:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:72:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:88:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(faces);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# neural_renderer/cuda/rasterize_cuda.cpp:70:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:70:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:72:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:89:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(face_index_map);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# neural_renderer/cuda/rasterize_cuda.cpp:70:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:70:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:72:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:90:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(weight_map);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/rasterize_cuda.cpp:1:
# neural_renderer/cuda/rasterize_cuda.cpp:70:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:70:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/rasterize_cuda.cpp:72:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# ...
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:17:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:19:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:29:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(textures);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/create_texture_image_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Device.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:7,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/create_texture_image_cuda.cpp:1:
# neural_renderer/cuda/create_texture_image_cuda.cpp:17:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                                           ^
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/macros/Macros.h:173:65: note: in definition of macro ‘C10_UNLIKELY’
#  #define C10_UNLIKELY(expr)  (__builtin_expect(static_cast<bool>(expr), 0))
#                                                                  ^~~~
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/c10/util/Exception.h:362:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#    if (C10_UNLIKELY_OR_CONST(!(cond))) {                                 \
#        ^~~~~~~~~~~~~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:17:23: note: in expansion of macro ‘TORCH_CHECK’
#  #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#                        ^~~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:19:24: note: in expansion of macro ‘CHECK_CUDA’
#  #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#                         ^~~~~~~~~~
# neural_renderer/cuda/create_texture_image_cuda.cpp:30:5: note: in expansion of macro ‘CHECK_INPUT’
#      CHECK_INPUT(image);
#      ^~~~~~~~~~~
# In file included from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Tensor.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/Context.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/ATen.h:9,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from neural_renderer/cuda/create_texture_image_cuda.cpp:1:
# /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/ATen/core/TensorBody.h:303:30: note: declared here
#    DeprecatedTypeProperties & type() const {
#                               ^~~~
# /share/apps/cuda/10.2.89/bin/nvcc -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/torch/csrc/api/include -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/TH -I/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/include/THC -I/share/apps/cuda/10.2.89/include -I/scratch/nv2095/new_env/new_env/include/python3.6m -c neural_renderer/cuda/create_texture_image_cuda_kernel.cu -o build/temp.linux-x86_64-3.6/neural_renderer/cuda/create_texture_image_cuda_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_gcc" -DPYBIND11_STDLIB="_libstdcpp" -DPYBIND11_BUILD_ABI="_cxxabi1011" -DTORCH_EXTENSION_NAME=create_texture_image -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_70,code=compute_70 -gencode=arch=compute_70,code=sm_70 -std=c++14
# g++ -pthread -shared -B /scratch/nv2095/new_env/new_env/compiler_compat -L/scratch/nv2095/new_env/new_env/lib -Wl,-rpath=/scratch/nv2095/new_env/new_env/lib -Wl,--no-as-needed -Wl,--sysroot=/ build/temp.linux-x86_64-3.6/neural_renderer/cuda/create_texture_image_cuda.o build/temp.linux-x86_64-3.6/neural_renderer/cuda/create_texture_image_cuda_kernel.o -L/scratch/nv2095/new_env/new_env/lib/python3.6/site-packages/torch/lib -L/share/apps/cuda/10.2.89/lib64 -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-3.6/neural_renderer/cuda/create_texture_image.cpython-36m-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/vertices_to_faces.py -> build/bdist.linux-x86_64/egg/neural_renderer
# creating build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.6/neural_renderer/cuda/__init__.py -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.6/neural_renderer/cuda/create_texture_image.cpython-36m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.6/neural_renderer/cuda/load_textures.cpython-36m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.6/neural_renderer/cuda/rasterize.cpython-36m-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.6/neural_renderer/lighting.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/load_obj.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/projection.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/perspective.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/__init__.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/mesh.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/look.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/save_obj.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/look_at.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/rasterize.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/get_points_from_angles.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.6/neural_renderer/renderer.py -> build/bdist.linux-x86_64/egg/neural_renderer
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/vertices_to_faces.py to vertices_to_faces.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/lighting.py to lighting.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/load_obj.py to load_obj.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/projection.py to projection.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/perspective.py to perspective.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/mesh.py to mesh.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/look.py to look.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/save_obj.py to save_obj.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/look_at.py to look_at.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/rasterize.py to rasterize.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/get_points_from_angles.py to get_points_from_angles.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/renderer.py to renderer.cpython-36.pyc
# creating stub loader for neural_renderer/cuda/load_textures.cpython-36m-x86_64-linux-gnu.so
# creating stub loader for neural_renderer/cuda/rasterize.cpython-36m-x86_64-linux-gnu.so
# creating stub loader for neural_renderer/cuda/create_texture_image.cpython-36m-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/load_textures.py to load_textures.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/rasterize.py to rasterize.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/create_texture_image.py to create_texture_image.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# neural_renderer.cuda.__pycache__.create_texture_image.cpython-36: module references __file__
# neural_renderer.cuda.__pycache__.load_textures.cpython-36: module references __file__
# neural_renderer.cuda.__pycache__.rasterize.cpython-36: module references __file__
# creating dist
# creating 'dist/neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg
# removing '/home/nv2095/.local/lib/python3.6/site-packages/neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg' (and everything under it)
# creating /home/nv2095/.local/lib/python3.6/site-packages/neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg
# Extracting neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg to /home/nv2095/.local/lib/python3.6/site-packages
# neural-renderer-pytorch 1.1.3 is already the active version in easy-install.pth
#
# Installed /home/nv2095/.local/lib/python3.6/site-packages/neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg
# Processing dependencies for neural-renderer-pytorch==1.1.3
# Finished processing dependencies for neural-renderer-pytorch==1.1.3

# %%
# !pip install ipykernel
# Out:
# Collecting ipykernel
#   Downloading ipykernel-5.5.6-py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 32.7 MB/s eta 0:00:01
# Collecting traitlets>=4.1.0
#   Downloading traitlets-4.3.3-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 5.9 MB/s s eta 0:00:01
# Collecting tornado>=4.2
#   Downloading tornado-6.1-cp36-cp36m-manylinux2010_x86_64.whl (427 kB)
#      |████████████████████████████████| 427 kB 150.1 MB/s eta 0:00:01
# Collecting ipython>=5.0.0
#   Downloading ipython-7.16.3-py3-none-any.whl (783 kB)
#      |████████████████████████████████| 783 kB 112.8 MB/s eta 0:00:01
# Collecting jupyter-client
#   Downloading jupyter_client-7.1.2-py3-none-any.whl (130 kB)
#      |████████████████████████████████| 130 kB 153.4 MB/s eta 0:00:01
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Requirement already satisfied: decorator in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (4.4.2)
# Collecting jedi<=0.17.2,>=0.10
#   Downloading jedi-0.17.2-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 144.4 MB/s eta 0:00:01
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.29-py3-none-any.whl (381 kB)
#      |████████████████████████████████| 381 kB 147.2 MB/s eta 0:00:01
# Collecting pexpect
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 2.2 MB/s s eta 0:00:01
# Requirement already satisfied: setuptools>=18.5 in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel) (58.0.4)
# Collecting pygments
#   Downloading Pygments-2.12.0-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 143.4 MB/s eta 0:00:01
# Collecting parso<0.8.0,>=0.7.0
#   Downloading parso-0.7.1-py2.py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 152.4 MB/s eta 0:00:01
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: six in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from traitlets>=4.1.0->ipykernel) (1.16.0)
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: python-dateutil>=2.1 in /scratch/nv2095/new_env/new_env/lib/python3.6/site-packages (from jupyter-client->ipykernel) (2.8.2)
# Collecting pyzmq>=13
#   Downloading pyzmq-22.3.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 137.7 MB/s eta 0:00:01
# Collecting jupyter-core>=4.6.0
#   Downloading jupyter_core-4.9.2-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 8.7 MB/s s eta 0:00:01
# Collecting nest-asyncio>=1.5
#   Downloading nest_asyncio-1.5.5-py3-none-any.whl (5.2 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Installing collected packages: ipython-genutils, wcwidth, traitlets, ptyprocess, parso, tornado, pyzmq, pygments, prompt-toolkit, pickleshare, pexpect, nest-asyncio, jupyter-core, jedi, entrypoints, backcall, jupyter-client, ipython, ipykernel
# Successfully installed backcall-0.2.0 entrypoints-0.4 ipykernel-5.5.6 ipython-7.16.3 ipython-genutils-0.2.0 jedi-0.17.2 jupyter-client-7.1.2 jupyter-core-4.9.2 nest-asyncio-1.5.5 parso-0.7.1 pexpect-4.8.0 pickleshare-0.7.5 prompt-toolkit-3.0.29 ptyprocess-0.7.0 pygments-2.12.0 pyzmq-22.3.0 tornado-6.1 traitlets-4.3.3 wcwidth-0.2.5

# %%
# !cd scripts/ && ls && bash ./run.sh
# Out:
# data  run.sh
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/scratch/nv2095/new_project/StyleTransferUsingNeuralRenderer/style_transfer/src/main/StyleLoss.py:50: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /scratch/nv2095/new_project/StyleTransferUsingNeuralRenderer/style_transfer/src/main/StyleLoss.py:51: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# Optimizing. Loss 292762.9062: 100%|###########| 100/100 [00:24<00:00,  4.01it/s]
# Saving the object after performing style transfer
# Drawing:   0%|                                           | 0/90 [00:00<?, ?it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0000.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.029842399060726166, 0.056513480842113495]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   0%|                                           | 0/90 [00:00<?, ?it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0001.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.027377068996429443, 0.05672125145792961]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   0%|                                           | 0/90 [00:00<?, ?it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0002.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.030162276700139046, 0.056917864829301834]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   0%|                                           | 0/90 [00:00<?, ?it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0003.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.027541227638721466, 0.05713938921689987]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   4%|#5                                 | 4/90 [00:00<00:02, 31.17it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0004.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.030205324292182922, 0.05695611611008644]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   4%|#5                                 | 4/90 [00:00<00:02, 31.17it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0005.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.028375893831253052, 0.0570666566491127]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   4%|#5                                 | 4/90 [00:00<00:02, 31.17it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0006.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.029263626784086227, 0.057047516107559204]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   4%|#5                                 | 4/90 [00:00<00:02, 31.17it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0007.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02990615740418434, 0.05729949101805687]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   9%|###1                               | 8/90 [00:00<00:02, 31.38it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0008.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02874692529439926, 0.05733829736709595]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   9%|###1                               | 8/90 [00:00<00:02, 31.38it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0009.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.029806766659021378, 0.056955449283123016]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   9%|###1                               | 8/90 [00:00<00:02, 31.38it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0010.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.028602130711078644, 0.056319307535886765]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   9%|###1                               | 8/90 [00:00<00:02, 31.38it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0011.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.028355615213513374, 0.05714338645339012]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  13%|####5                             | 12/90 [00:00<00:02, 32.13it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0012.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.029805757105350494, 0.05636795610189438]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  13%|####5                             | 12/90 [00:00<00:02, 32.13it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0013.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02892618626356125, 0.056504540145397186]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  13%|####5                             | 12/90 [00:00<00:02, 32.13it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0014.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.027842450886964798, 0.05699963867664337]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  13%|####5                             | 12/90 [00:00<00:02, 32.13it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0015.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02932928502559662, 0.05722925066947937]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  18%|######                            | 16/90 [00:00<00:02, 32.63it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0016.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.029709864407777786, 0.056973494589328766]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  18%|######                            | 16/90 [00:00<00:02, 32.63it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0017.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02697126194834709, 0.05622871220111847]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  18%|######                            | 16/90 [00:00<00:02, 32.63it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0018.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02901560440659523, 0.05626465380191803]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  18%|######                            | 16/90 [00:00<00:02, 32.63it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0019.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.029651138931512833, 0.05719898268580437]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  22%|#######5                          | 20/90 [00:00<00:02, 33.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0020.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.027395501732826233, 0.05591287091374397]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  22%|#######5                          | 20/90 [00:00<00:02, 33.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0021.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.029712937772274017, 0.0572226345539093]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  22%|#######5                          | 20/90 [00:00<00:02, 33.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0022.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.027793720364570618, 0.056694868952035904]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  22%|#######5                          | 20/90 [00:00<00:02, 33.27it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0023.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.028914012014865875, 0.05630792677402496]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  27%|#########                         | 24/90 [00:00<00:01, 33.93it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0024.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.029428454115986824, 0.05649304389953613]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  27%|#########                         | 24/90 [00:00<00:01, 33.93it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0025.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.028079936280846596, 0.057196952402591705]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  27%|#########                         | 24/90 [00:00<00:01, 33.93it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0026.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.029396673664450645, 0.05665035545825958]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  27%|#########                         | 24/90 [00:00<00:01, 33.93it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0027.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.028138548135757446, 0.05660264939069748]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  31%|##########5                       | 28/90 [00:00<00:01, 34.55it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0028.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.026853568851947784, 0.055191896855831146]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  31%|##########5                       | 28/90 [00:00<00:01, 34.55it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0029.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.029057079926133156, 0.056477077305316925]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  31%|##########5                       | 28/90 [00:00<00:01, 34.55it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0030.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.028961054980754852, 0.054311711341142654]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  31%|##########5                       | 28/90 [00:00<00:01, 34.55it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0031.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.026556503027677536, 0.05408177152276039]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  36%|############                      | 32/90 [00:00<00:01, 35.22it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0032.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.025315169245004654, 0.05464692786335945]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  36%|############                      | 32/90 [00:00<00:01, 35.22it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0033.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02909824438393116, 0.05406194180250168]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  36%|############                      | 32/90 [00:01<00:01, 35.22it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0034.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02111339382827282, 0.05426661670207977]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  36%|############                      | 32/90 [00:01<00:01, 35.22it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0035.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.025809597223997116, 0.053827837109565735]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  40%|#############6                    | 36/90 [00:01<00:01, 35.54it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0036.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02483561262488365, 0.054521575570106506]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  40%|#############6                    | 36/90 [00:01<00:01, 35.54it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0037.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.018702413886785507, 0.05335204303264618]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  40%|#############6                    | 36/90 [00:01<00:01, 35.54it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0038.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.022519513964653015, 0.05317537486553192]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  40%|#############6                    | 36/90 [00:01<00:01, 35.54it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0039.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.01840304397046566, 0.05422314256429672]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  44%|###############1                  | 40/90 [00:01<00:01, 35.47it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0040.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.017797164618968964, 0.05298825725913048]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  44%|###############1                  | 40/90 [00:01<00:01, 35.47it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0041.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.017366422340273857, 0.05299578234553337]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  44%|###############1                  | 40/90 [00:01<00:01, 35.47it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0042.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.01761399209499359, 0.05258162319660187]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  44%|###############1                  | 40/90 [00:01<00:01, 35.47it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0043.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.016774747520685196, 0.05350801348686218]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  49%|################6                 | 44/90 [00:01<00:01, 35.39it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0044.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.017991404980421066, 0.05231446772813797]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  49%|################6                 | 44/90 [00:01<00:01, 35.39it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0045.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.016924692317843437, 0.05208982899785042]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  49%|################6                 | 44/90 [00:01<00:01, 35.39it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0046.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.01792484149336815, 0.0523647665977478]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  49%|################6                 | 44/90 [00:01<00:01, 35.39it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0047.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.019846580922603607, 0.05245114862918854]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  53%|##################1               | 48/90 [00:01<00:01, 35.16it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0048.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.017297256737947464, 0.05197380483150482]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  53%|##################1               | 48/90 [00:01<00:01, 35.16it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0049.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.020343609154224396, 0.052813563495874405]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  53%|##################1               | 48/90 [00:01<00:01, 35.16it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0050.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021110309287905693, 0.05280390381813049]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  53%|##################1               | 48/90 [00:01<00:01, 35.16it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0051.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.019959736615419388, 0.05294376239180565]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  58%|###################6              | 52/90 [00:01<00:01, 34.85it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0052.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021091395989060402, 0.05223512649536133]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  58%|###################6              | 52/90 [00:01<00:01, 34.85it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0053.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021079109981656075, 0.05260850489139557]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  58%|###################6              | 52/90 [00:01<00:01, 34.85it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0054.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.020704617723822594, 0.05199164152145386]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  58%|###################6              | 52/90 [00:01<00:01, 34.85it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0055.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021212052553892136, 0.05217774212360382]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  62%|#####################1            | 56/90 [00:01<00:00, 34.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0056.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02057061716914177, 0.05204741656780243]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  62%|#####################1            | 56/90 [00:01<00:00, 34.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0057.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021148739382624626, 0.05237497389316559]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  62%|#####################1            | 56/90 [00:01<00:00, 34.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0058.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.020714171230793, 0.052182815968990326]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  62%|#####################1            | 56/90 [00:01<00:00, 34.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0059.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021080974489450455, 0.05264808237552643]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  67%|######################6           | 60/90 [00:01<00:00, 34.93it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0060.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.020870467647910118, 0.052351269870996475]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  67%|######################6           | 60/90 [00:01<00:00, 34.93it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0061.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.022432856261730194, 0.05268452316522598]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  67%|######################6           | 60/90 [00:01<00:00, 34.93it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0062.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.019534742459654808, 0.05222630873322487]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  67%|######################6           | 60/90 [00:01<00:00, 34.93it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0063.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021436113864183426, 0.0521271750330925]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  71%|########################1         | 64/90 [00:01<00:00, 34.92it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0064.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021420173346996307, 0.05205915495753288]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  71%|########################1         | 64/90 [00:01<00:00, 34.92it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0065.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02349286526441574, 0.052143730223178864]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  71%|########################1         | 64/90 [00:01<00:00, 34.92it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0066.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021708521991968155, 0.052655111998319626]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  71%|########################1         | 64/90 [00:01<00:00, 34.92it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0067.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.0204949788749218, 0.05217835307121277]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  76%|#########################6        | 68/90 [00:01<00:00, 34.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0068.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02319834940135479, 0.05180751532316208]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  76%|#########################6        | 68/90 [00:02<00:00, 34.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0069.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02183050662279129, 0.05177799612283707]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  76%|#########################6        | 68/90 [00:02<00:00, 34.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0070.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02097148634493351, 0.051471590995788574]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  76%|#########################6        | 68/90 [00:02<00:00, 34.86it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0071.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02252162992954254, 0.05106610804796219]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  80%|###########################2      | 72/90 [00:02<00:00, 33.77it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0072.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021449871361255646, 0.050866931676864624]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  80%|###########################2      | 72/90 [00:02<00:00, 33.77it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0073.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.023221896961331367, 0.050984106957912445]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  80%|###########################2      | 72/90 [00:02<00:00, 33.77it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0074.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.022867657244205475, 0.05125880241394043]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  80%|###########################2      | 72/90 [00:02<00:00, 33.77it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0075.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021955059841275215, 0.05170486122369766]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  84%|############################7     | 76/90 [00:02<00:00, 32.87it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0076.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.021996906027197838, 0.052676595747470856]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  84%|############################7     | 76/90 [00:02<00:00, 32.87it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0077.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.023547373712062836, 0.05323058366775513]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  84%|############################7     | 76/90 [00:02<00:00, 32.87it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0078.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.022962331771850586, 0.05319834128022194]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  84%|############################7     | 76/90 [00:02<00:00, 32.87it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0079.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02288728766143322, 0.05470583960413933]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  89%|##############################2   | 80/90 [00:02<00:00, 32.20it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0080.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.025899959728121758, 0.05451551824808121]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  89%|##############################2   | 80/90 [00:02<00:00, 32.20it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0081.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.025963593274354935, 0.055148396641016006]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  89%|##############################2   | 80/90 [00:02<00:00, 32.20it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0082.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.023370102047920227, 0.055291514843702316]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  89%|##############################2   | 80/90 [00:02<00:00, 32.20it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0083.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.027021460235118866, 0.056193556636571884]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  93%|###############################7  | 84/90 [00:02<00:00, 31.76it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0084.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.027854876592755318, 0.05566586181521416]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  93%|###############################7  | 84/90 [00:02<00:00, 31.76it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0085.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.025700144469738007, 0.05618090182542801]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  93%|###############################7  | 84/90 [00:02<00:00, 31.76it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0086.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.02937016822397709, 0.0558842197060585]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  93%|###############################7  | 84/90 [00:02<00:00, 31.76it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0087.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.029170572757720947, 0.056818027049303055]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  98%|#################################2| 88/90 [00:02<00:00, 31.14it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0088.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.028099482879042625, 0.05669490993022919]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  98%|#################################2| 88/90 [00:02<00:00, 31.14it/s]./../main/run.py:98: UserWarning: /tmp/_tmp_0089.png is a low contrast image
#   imsave('/tmp/_tmp_%04d.png' % num, image)
# Lossy conversion from float32 to uint8. Range [-0.027705691754817963, 0.056933533400297165]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing: 100%|##################################| 90/90 [00:02<00:00, 33.43it/s]
# Saving the object after style transfer.
# the file name is ./data/results/stylized_teapot.obj
# /home/nv2095/.local/lib/python3.6/site-packages/neural_renderer_pytorch-1.1.3-py3.6-linux-x86_64.egg/neural_renderer/save_obj.py:50: UserWarning: ./data/results/stylized_teapot.png is a low contrast image
#   imsave(filename_texture, texture_image)
# Lossy conversion from float32 to uint8. Range [-0.03965108096599579, 0.060927703976631165]. Convert image to uint8 prior to saving to suppress this warning.
# Generating texture mapping for the generated stylized object.
# Optimizing: 100%|#############################| 300/300 [00:36<00:00,  8.14it/s]
# Drawing:   0%|                                           | 0/90 [00:00<?, ?it/s]Lossy conversion from float32 to uint8. Range [-0.15902885794639587, 0.8669735193252563]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   1%|3                                  | 1/90 [00:00<00:14,  6.33it/s]Lossy conversion from float32 to uint8. Range [-0.17716172337532043, 0.8538267016410828]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   1%|3                                  | 1/90 [00:00<00:14,  6.33it/s]Lossy conversion from float32 to uint8. Range [-0.2030375599861145, 0.8435848951339722]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   1%|3                                  | 1/90 [00:00<00:14,  6.33it/s]Lossy conversion from float32 to uint8. Range [-0.16108110547065735, 0.8165766000747681]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   4%|#5                                 | 4/90 [00:00<00:05, 16.80it/s]Lossy conversion from float32 to uint8. Range [-0.18281245231628418, 0.8146983981132507]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   4%|#5                                 | 4/90 [00:00<00:05, 16.80it/s]Lossy conversion from float32 to uint8. Range [-0.21047627925872803, 0.8677749037742615]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   4%|#5                                 | 4/90 [00:00<00:05, 16.80it/s]Lossy conversion from float32 to uint8. Range [-0.41391459107398987, 0.8891862630844116]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   8%|##7                                | 7/90 [00:00<00:03, 21.03it/s]Lossy conversion from float32 to uint8. Range [-0.20735320448875427, 0.8554514646530151]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   8%|##7                                | 7/90 [00:00<00:03, 21.03it/s]Lossy conversion from float32 to uint8. Range [-0.20983323454856873, 0.8623534440994263]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:   8%|##7                                | 7/90 [00:00<00:03, 21.03it/s]Lossy conversion from float32 to uint8. Range [-0.22500385344028473, 0.8256343603134155]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  11%|###7                              | 10/90 [00:00<00:03, 23.59it/s]Lossy conversion from float32 to uint8. Range [-0.23665544390678406, 0.8364799618721008]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  11%|###7                              | 10/90 [00:00<00:03, 23.59it/s]Lossy conversion from float32 to uint8. Range [-0.25192147493362427, 0.8596400022506714]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  11%|###7                              | 10/90 [00:00<00:03, 23.59it/s]Lossy conversion from float32 to uint8. Range [-0.16345781087875366, 0.8551959991455078]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  11%|###7                              | 10/90 [00:00<00:03, 23.59it/s]Lossy conversion from float32 to uint8. Range [-0.06987135857343674, 0.8345137238502502]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  16%|#####2                            | 14/90 [00:00<00:02, 26.38it/s]Lossy conversion from float32 to uint8. Range [-0.07803869992494583, 0.8151975274085999]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  16%|#####2                            | 14/90 [00:00<00:02, 26.38it/s]Lossy conversion from float32 to uint8. Range [-0.11978726089000702, 0.8626358509063721]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  16%|#####2                            | 14/90 [00:00<00:02, 26.38it/s]Lossy conversion from float32 to uint8. Range [-0.13713040947914124, 0.8930838108062744]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  16%|#####2                            | 14/90 [00:00<00:02, 26.38it/s]Lossy conversion from float32 to uint8. Range [-0.21521124243736267, 0.8429728746414185]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  20%|######8                           | 18/90 [00:00<00:02, 28.59it/s]Lossy conversion from float32 to uint8. Range [-0.1644829511642456, 0.8479852080345154]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  20%|######8                           | 18/90 [00:00<00:02, 28.59it/s]Lossy conversion from float32 to uint8. Range [-0.23645396530628204, 0.8593659400939941]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  20%|######8                           | 18/90 [00:00<00:02, 28.59it/s]Lossy conversion from float32 to uint8. Range [-0.18623599410057068, 0.8610799908638]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  20%|######8                           | 18/90 [00:00<00:02, 28.59it/s]Lossy conversion from float32 to uint8. Range [-0.21539920568466187, 0.8562003970146179]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  24%|########3                         | 22/90 [00:00<00:02, 30.21it/s]Lossy conversion from float32 to uint8. Range [-0.25833576917648315, 0.845065712928772]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  24%|########3                         | 22/90 [00:00<00:02, 30.21it/s]Lossy conversion from float32 to uint8. Range [-0.15670669078826904, 0.8304364681243896]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  24%|########3                         | 22/90 [00:00<00:02, 30.21it/s]Lossy conversion from float32 to uint8. Range [-0.2046252340078354, 0.8400118947029114]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  24%|########3                         | 22/90 [00:00<00:02, 30.21it/s]Lossy conversion from float32 to uint8. Range [-0.14613845944404602, 0.8480486869812012]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  29%|#########8                        | 26/90 [00:00<00:02, 31.92it/s]Lossy conversion from float32 to uint8. Range [-0.2028324455022812, 0.8577046394348145]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  29%|#########8                        | 26/90 [00:00<00:02, 31.92it/s]Lossy conversion from float32 to uint8. Range [-0.1829892098903656, 0.8786717057228088]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  29%|#########8                        | 26/90 [00:01<00:02, 31.92it/s]Lossy conversion from float32 to uint8. Range [-0.27390897274017334, 0.89125657081604]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  29%|#########8                        | 26/90 [00:01<00:02, 31.92it/s]Lossy conversion from float32 to uint8. Range [-0.28359973430633545, 0.8744519352912903]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  33%|###########3                      | 30/90 [00:01<00:01, 33.17it/s]Lossy conversion from float32 to uint8. Range [-0.2392650842666626, 0.852422833442688]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  33%|###########3                      | 30/90 [00:01<00:01, 33.17it/s]Lossy conversion from float32 to uint8. Range [-0.25184351205825806, 0.8333497643470764]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  33%|###########3                      | 30/90 [00:01<00:01, 33.17it/s]Lossy conversion from float32 to uint8. Range [-0.1556272953748703, 0.8361846804618835]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  33%|###########3                      | 30/90 [00:01<00:01, 33.17it/s]Lossy conversion from float32 to uint8. Range [-0.18748891353607178, 0.8497374057769775]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  38%|############8                     | 34/90 [00:01<00:01, 33.99it/s]Lossy conversion from float32 to uint8. Range [-0.15997640788555145, 0.8614427447319031]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  38%|############8                     | 34/90 [00:01<00:01, 33.99it/s]Lossy conversion from float32 to uint8. Range [-0.2169603556394577, 0.9089267253875732]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  38%|############8                     | 34/90 [00:01<00:01, 33.99it/s]Lossy conversion from float32 to uint8. Range [-0.189639151096344, 0.8370625972747803]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  38%|############8                     | 34/90 [00:01<00:01, 33.99it/s]Lossy conversion from float32 to uint8. Range [-0.23162701725959778, 0.9141574501991272]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  42%|##############3                   | 38/90 [00:01<00:01, 33.99it/s]Lossy conversion from float32 to uint8. Range [-0.1745639145374298, 0.8310654759407043]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  42%|##############3                   | 38/90 [00:01<00:01, 33.99it/s]Lossy conversion from float32 to uint8. Range [-0.17211638391017914, 0.8386577367782593]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  42%|##############3                   | 38/90 [00:01<00:01, 33.99it/s]Lossy conversion from float32 to uint8. Range [-0.16924910247325897, 0.8296162486076355]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  42%|##############3                   | 38/90 [00:01<00:01, 33.99it/s]Lossy conversion from float32 to uint8. Range [-0.1791267842054367, 0.8384490013122559]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  47%|###############8                  | 42/90 [00:01<00:01, 33.49it/s]Lossy conversion from float32 to uint8. Range [-0.20093216001987457, 0.8346669673919678]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  47%|###############8                  | 42/90 [00:01<00:01, 33.49it/s]Lossy conversion from float32 to uint8. Range [-0.19035501778125763, 0.8172451257705688]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  47%|###############8                  | 42/90 [00:01<00:01, 33.49it/s]Lossy conversion from float32 to uint8. Range [-0.18665733933448792, 0.8505698442459106]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  47%|###############8                  | 42/90 [00:01<00:01, 33.49it/s]Lossy conversion from float32 to uint8. Range [-0.22497685253620148, 0.8981258273124695]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  51%|#################3                | 46/90 [00:01<00:01, 33.11it/s]Lossy conversion from float32 to uint8. Range [-0.16087280213832855, 0.8475919961929321]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  51%|#################3                | 46/90 [00:01<00:01, 33.11it/s]Lossy conversion from float32 to uint8. Range [-0.14794352650642395, 0.8180111646652222]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  51%|#################3                | 46/90 [00:01<00:01, 33.11it/s]Lossy conversion from float32 to uint8. Range [-0.15403123199939728, 0.8508569002151489]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  51%|#################3                | 46/90 [00:01<00:01, 33.11it/s]Lossy conversion from float32 to uint8. Range [-0.2043939232826233, 0.8152472376823425]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  56%|##################8               | 50/90 [00:01<00:01, 32.71it/s]Lossy conversion from float32 to uint8. Range [-0.26232588291168213, 0.8238868713378906]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  56%|##################8               | 50/90 [00:01<00:01, 32.71it/s]Lossy conversion from float32 to uint8. Range [-0.20622611045837402, 0.8589410185813904]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  56%|##################8               | 50/90 [00:01<00:01, 32.71it/s]Lossy conversion from float32 to uint8. Range [-0.21836349368095398, 0.8123570680618286]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  56%|##################8               | 50/90 [00:01<00:01, 32.71it/s]Lossy conversion from float32 to uint8. Range [-0.21679294109344482, 0.8054341077804565]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  60%|####################4             | 54/90 [00:01<00:01, 32.45it/s]Lossy conversion from float32 to uint8. Range [-0.18168723583221436, 0.8366068601608276]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  60%|####################4             | 54/90 [00:01<00:01, 32.45it/s]Lossy conversion from float32 to uint8. Range [-0.17850178480148315, 0.8217029571533203]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  60%|####################4             | 54/90 [00:01<00:01, 32.45it/s]Lossy conversion from float32 to uint8. Range [-0.1743420660495758, 0.8860738277435303]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  60%|####################4             | 54/90 [00:01<00:01, 32.45it/s]Lossy conversion from float32 to uint8. Range [-0.179195836186409, 0.9170779585838318]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  64%|#####################9            | 58/90 [00:01<00:00, 32.78it/s]Lossy conversion from float32 to uint8. Range [-0.1963762491941452, 0.8525575399398804]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  64%|#####################9            | 58/90 [00:01<00:00, 32.78it/s]Lossy conversion from float32 to uint8. Range [-0.3200884163379669, 0.8419995307922363]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  64%|#####################9            | 58/90 [00:01<00:00, 32.78it/s]Lossy conversion from float32 to uint8. Range [-0.3587092459201813, 0.8252725601196289]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  64%|#####################9            | 58/90 [00:02<00:00, 32.78it/s]Lossy conversion from float32 to uint8. Range [-0.21199801564216614, 0.8501211404800415]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  69%|#######################4          | 62/90 [00:02<00:00, 33.20it/s]Lossy conversion from float32 to uint8. Range [-0.1642342060804367, 0.8147484660148621]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  69%|#######################4          | 62/90 [00:02<00:00, 33.20it/s]Lossy conversion from float32 to uint8. Range [-0.15075480937957764, 0.8212664723396301]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  69%|#######################4          | 62/90 [00:02<00:00, 33.20it/s]Lossy conversion from float32 to uint8. Range [-0.23514504730701447, 0.834528386592865]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  69%|#######################4          | 62/90 [00:02<00:00, 33.20it/s]Lossy conversion from float32 to uint8. Range [-0.3202226161956787, 0.8034976124763489]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  73%|########################9         | 66/90 [00:02<00:00, 33.32it/s]Lossy conversion from float32 to uint8. Range [-0.0841645896434784, 0.8299309611320496]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  73%|########################9         | 66/90 [00:02<00:00, 33.32it/s]Lossy conversion from float32 to uint8. Range [-0.10446546971797943, 0.8041183948516846]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  73%|########################9         | 66/90 [00:02<00:00, 33.32it/s]Lossy conversion from float32 to uint8. Range [-0.09263427555561066, 0.8283216953277588]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  73%|########################9         | 66/90 [00:02<00:00, 33.32it/s]Lossy conversion from float32 to uint8. Range [-0.15968161821365356, 0.8113542199134827]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  78%|##########################4       | 70/90 [00:02<00:00, 33.33it/s]Lossy conversion from float32 to uint8. Range [-0.12243303656578064, 0.831815242767334]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  78%|##########################4       | 70/90 [00:02<00:00, 33.33it/s]Lossy conversion from float32 to uint8. Range [-0.16351407766342163, 0.8246179223060608]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  78%|##########################4       | 70/90 [00:02<00:00, 33.33it/s]Lossy conversion from float32 to uint8. Range [-0.137490376830101, 0.8124006986618042]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  78%|##########################4       | 70/90 [00:02<00:00, 33.33it/s]Lossy conversion from float32 to uint8. Range [-0.1059890016913414, 0.8749393820762634]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  82%|###########################9      | 74/90 [00:02<00:00, 32.78it/s]Lossy conversion from float32 to uint8. Range [-0.12316091358661652, 0.8894356489181519]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  82%|###########################9      | 74/90 [00:02<00:00, 32.78it/s]Lossy conversion from float32 to uint8. Range [-0.14723029732704163, 0.8358849287033081]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  82%|###########################9      | 74/90 [00:02<00:00, 32.78it/s]Lossy conversion from float32 to uint8. Range [-0.14311476051807404, 0.870053231716156]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  82%|###########################9      | 74/90 [00:02<00:00, 32.78it/s]Lossy conversion from float32 to uint8. Range [-0.1234145313501358, 0.8186036348342896]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  87%|#############################4    | 78/90 [00:02<00:00, 31.95it/s]Lossy conversion from float32 to uint8. Range [-0.10695185512304306, 0.8846923112869263]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  87%|#############################4    | 78/90 [00:02<00:00, 31.95it/s]Lossy conversion from float32 to uint8. Range [-0.13610118627548218, 0.8608840703964233]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  87%|#############################4    | 78/90 [00:02<00:00, 31.95it/s]Lossy conversion from float32 to uint8. Range [-0.09429105371236801, 0.8705264925956726]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  87%|#############################4    | 78/90 [00:02<00:00, 31.95it/s]Lossy conversion from float32 to uint8. Range [-0.09956057369709015, 0.8162505626678467]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  91%|##############################9   | 82/90 [00:02<00:00, 30.85it/s]Lossy conversion from float32 to uint8. Range [-0.43832939863204956, 0.8067266941070557]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  91%|##############################9   | 82/90 [00:02<00:00, 30.85it/s]Lossy conversion from float32 to uint8. Range [-0.12056484073400497, 0.8299374580383301]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  91%|##############################9   | 82/90 [00:02<00:00, 30.85it/s]Lossy conversion from float32 to uint8. Range [-0.10779000073671341, 0.8200342655181885]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  91%|##############################9   | 82/90 [00:02<00:00, 30.85it/s]Lossy conversion from float32 to uint8. Range [-0.07206631451845169, 0.800849437713623]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  96%|################################4 | 86/90 [00:02<00:00, 29.53it/s]Lossy conversion from float32 to uint8. Range [-0.08015207946300507, 0.8531109094619751]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  96%|################################4 | 86/90 [00:02<00:00, 29.53it/s]Lossy conversion from float32 to uint8. Range [-0.09188339859247208, 0.8015673160552979]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  96%|################################4 | 86/90 [00:02<00:00, 29.53it/s]Lossy conversion from float32 to uint8. Range [-0.16770215332508087, 0.8216097354888916]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing:  99%|#################################6| 89/90 [00:02<00:00, 28.83it/s]Lossy conversion from float32 to uint8. Range [-0.16412344574928284, 0.8099221587181091]. Convert image to uint8 prior to saving to suppress this warning.
# Drawing: 100%|##################################| 90/90 [00:02<00:00, 30.21it/s]
# the file name is ./data/results/stylized_and_textured_teapot.obj
# Lossy conversion from float32 to uint8. Range [-2.7933566570281982, 3.1540534496307373]. Convert image to uint8 prior to saving to suppress this warning.
